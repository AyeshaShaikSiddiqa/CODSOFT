# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
df= pd.read_csv("Titanic-Dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Cabin']= df['Cabin'].fillna('Not Listed')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.dropna(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
pal= ['blue', 'yellow']
a= sns.countplot(data= df, x= df['Survived'], hue=df['Sex'], palette= pal)
for container in a.containers:
    a.bar_label(container)
plt.title("COUNT OF SURVIVORS AND CASUALTIES")
plt.xlabel("SURVIVED OR NOT")
plt.ylabel("COUNT")
plt.gca().set_xticklabels(['Casuality', 'Survived'])
plt.show()

# %%
pal1= ['pink', 'orange']
survivors= df[df['Survived']==1]
sns.histplot(data= survivors, x= survivors['Age'], bins= 15, hue=survivors['Sex'], palette= pal1)
plt.title("AGE OF SURVIVORS")
plt.xlabel('AGE')
plt.ylabel('COUNT')
plt.show()

# %%
notsurvivors= df[df['Survived']==0]
sns.histplot(data= notsurvivors, x= notsurvivors['Age'], bins= 15, hue= notsurvivors['Sex'], palette= pal)
plt.title("AGE OF CASULATIES")
plt.xlabel('AGE')
plt.ylabel('COUNT')
plt.show()

# %%
pal3=['#D84D4D', '#5ED84D','#D84D4D', '#5ED84D','#D84D4D', '#5ED84D']
plt.figure(figsize=(10, 6))
a=sns.countplot(data=df, x='Pclass', hue='Survived', palette= pal3)
for container in a.containers:
    a.bar_label(container)
plt.title('SURVIVOR AND CASUALTY COUNT BY CLASS')
plt.xlabel('CLASS')
plt.ylabel('COUNT')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.gca().set_xticklabels(['Class 1', 'Class 2', 'Class 3'])
plt.show()

# %%
df['Sex_numeric']= df['Sex'].apply(lambda x:1 if x=='female' else 0)
df[['Survived', 'Pclass', 'Age', 'Sex_numeric', 'SibSp', 'Parch', 'Fare']].corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_0ea4b_row0_col0, #T_0ea4b_row1_col1, #T_0ea4b_row2_col2, #T_0ea4b_row3_col3, #T_0ea4b_row4_col4, #T_0ea4b_row5_col5, #T_0ea4b_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0ea4b_row0_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_0ea4b_row0_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_0ea4b_row0_col3 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_0ea4b_row0_col4, #T_0ea4b_row4_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_0ea4b_row0_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_0ea4b_row0_col6, #T_0ea4b_row5_col4 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_0ea4b_row1_col0, #T_0ea4b_row1_col2, #T_0ea4b_row1_col3, #T_0ea4b_row1_col6, #T_0ea4b_row2_col4, #T_0ea4b_row2_col5, #T_0ea4b_row6_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0ea4b_row1_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_0ea4b_row1_col5 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_0ea4b_row2_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_0ea4b_row2_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_0ea4b_row2_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_0ea4b_row2_col6 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_0ea4b_row3_col0 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_0ea4b_row3_col1 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_0ea4b_row3_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_0ea4b_row3_col4 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_0ea4b_row3_col5 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_0ea4b_row3_col6 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_0ea4b_row4_col0 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_0ea4b_row4_col1 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_0ea4b_row4_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_0ea4b_row4_col5 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_0ea4b_row4_col6 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_0ea4b_row5_col0, #T_0ea4b_row6_col5 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_0ea4b_row5_col1 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_0ea4b_row5_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_0ea4b_row5_col3 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_0ea4b_row5_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_0ea4b_row6_col0 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_0ea4b_row6_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_0ea4b_row6_col3 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_0ea4b_row6_col4 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# </style>
# <table id="T_0ea4b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ea4b_level0_col0" class="col_heading level0 col0" >Survived</th>
#       <th id="T_0ea4b_level0_col1" class="col_heading level0 col1" >Pclass</th>
#       <th id="T_0ea4b_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_0ea4b_level0_col3" class="col_heading level0 col3" >Sex_numeric</th>
#       <th id="T_0ea4b_level0_col4" class="col_heading level0 col4" >SibSp</th>
#       <th id="T_0ea4b_level0_col5" class="col_heading level0 col5" >Parch</th>
#       <th id="T_0ea4b_level0_col6" class="col_heading level0 col6" >Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ea4b_level0_row0" class="row_heading level0 row0" >Survived</th>
#       <td id="T_0ea4b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0ea4b_row0_col1" class="data row0 col1" >-0.356462</td>
#       <td id="T_0ea4b_row0_col2" class="data row0 col2" >-0.082446</td>
#       <td id="T_0ea4b_row0_col3" class="data row0 col3" >0.536762</td>
#       <td id="T_0ea4b_row0_col4" class="data row0 col4" >-0.015523</td>
#       <td id="T_0ea4b_row0_col5" class="data row0 col5" >0.095265</td>
#       <td id="T_0ea4b_row0_col6" class="data row0 col6" >0.266100</td>
#     </tr>
#     <tr>
#       <th id="T_0ea4b_level0_row1" class="row_heading level0 row1" >Pclass</th>
#       <td id="T_0ea4b_row1_col0" class="data row1 col0" >-0.356462</td>
#       <td id="T_0ea4b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0ea4b_row1_col2" class="data row1 col2" >-0.365902</td>
#       <td id="T_0ea4b_row1_col3" class="data row1 col3" >-0.150826</td>
#       <td id="T_0ea4b_row1_col4" class="data row1 col4" >0.065187</td>
#       <td id="T_0ea4b_row1_col5" class="data row1 col5" >0.023666</td>
#       <td id="T_0ea4b_row1_col6" class="data row1 col6" >-0.552893</td>
#     </tr>
#     <tr>
#       <th id="T_0ea4b_level0_row2" class="row_heading level0 row2" >Age</th>
#       <td id="T_0ea4b_row2_col0" class="data row2 col0" >-0.082446</td>
#       <td id="T_0ea4b_row2_col1" class="data row2 col1" >-0.365902</td>
#       <td id="T_0ea4b_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0ea4b_row2_col3" class="data row2 col3" >-0.099037</td>
#       <td id="T_0ea4b_row2_col4" class="data row2 col4" >-0.307351</td>
#       <td id="T_0ea4b_row2_col5" class="data row2 col5" >-0.187896</td>
#       <td id="T_0ea4b_row2_col6" class="data row2 col6" >0.093143</td>
#     </tr>
#     <tr>
#       <th id="T_0ea4b_level0_row3" class="row_heading level0 row3" >Sex_numeric</th>
#       <td id="T_0ea4b_row3_col0" class="data row3 col0" >0.536762</td>
#       <td id="T_0ea4b_row3_col1" class="data row3 col1" >-0.150826</td>
#       <td id="T_0ea4b_row3_col2" class="data row3 col2" >-0.099037</td>
#       <td id="T_0ea4b_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_0ea4b_row3_col4" class="data row3 col4" >0.106296</td>
#       <td id="T_0ea4b_row3_col5" class="data row3 col5" >0.249543</td>
#       <td id="T_0ea4b_row3_col6" class="data row3 col6" >0.182457</td>
#     </tr>
#     <tr>
#       <th id="T_0ea4b_level0_row4" class="row_heading level0 row4" >SibSp</th>
#       <td id="T_0ea4b_row4_col0" class="data row4 col0" >-0.015523</td>
#       <td id="T_0ea4b_row4_col1" class="data row4 col1" >0.065187</td>
#       <td id="T_0ea4b_row4_col2" class="data row4 col2" >-0.307351</td>
#       <td id="T_0ea4b_row4_col3" class="data row4 col3" >0.106296</td>
#       <td id="T_0ea4b_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_0ea4b_row4_col5" class="data row4 col5" >0.383338</td>
#       <td id="T_0ea4b_row4_col6" class="data row4 col6" >0.139860</td>
#     </tr>
#     <tr>
#       <th id="T_0ea4b_level0_row5" class="row_heading level0 row5" >Parch</th>
#       <td id="T_0ea4b_row5_col0" class="data row5 col0" >0.095265</td>
#       <td id="T_0ea4b_row5_col1" class="data row5 col1" >0.023666</td>
#       <td id="T_0ea4b_row5_col2" class="data row5 col2" >-0.187896</td>
#       <td id="T_0ea4b_row5_col3" class="data row5 col3" >0.249543</td>
#       <td id="T_0ea4b_row5_col4" class="data row5 col4" >0.383338</td>
#       <td id="T_0ea4b_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_0ea4b_row5_col6" class="data row5 col6" >0.206624</td>
#     </tr>
#     <tr>
#       <th id="T_0ea4b_level0_row6" class="row_heading level0 row6" >Fare</th>
#       <td id="T_0ea4b_row6_col0" class="data row6 col0" >0.266100</td>
#       <td id="T_0ea4b_row6_col1" class="data row6 col1" >-0.552893</td>
#       <td id="T_0ea4b_row6_col2" class="data row6 col2" >0.093143</td>
#       <td id="T_0ea4b_row6_col3" class="data row6 col3" >0.182457</td>
#       <td id="T_0ea4b_row6_col4" class="data row6 col4" >0.139860</td>
#       <td id="T_0ea4b_row6_col5" class="data row6 col5" >0.206624</td>
#       <td id="T_0ea4b_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.model_selection import train_test_split
X= df[['Sex_numeric', 'Parch', 'Fare']]
y= df['Survived']
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size= 0.3, random_state= 42)
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred= lr.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.7663551401869159

# %%
from sklearn.metrics import confusion_matrix
conf_matrix = pd.DataFrame(confusion_matrix(y_test, y_pred))
conf_matrix
# Out:
#      0   1
# 0  104  18
# 1   32  60
